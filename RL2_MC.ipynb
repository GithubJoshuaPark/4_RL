# %% [markdown]
# # 강화 학습 (Reinforcement learning) 2

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from collections import defaultdict

# %% [markdown]
# ## Monte Carlo : blackjack first visit

# %%
## variable init
stick_threshold = 18
win_cnt = 0
lose_cnt = 0
draw_cnt = 0
num_episodes = 100_000

GAMMA = 1

# %%
env = gym.make("Blackjack-v1", sab = True)

def pi(state):
    return 0 if state[0] >= stick_threshold else 1

# s, _ = env.reset()
# action = pi(s)
# print("action = ", action)
# env.step(action)

# %%
## V, Returns Table
V = defaultdict(float)
Returns = defaultdict(list)

# %%
# num_episodes = 100000
for i in range(num_episodes):

    episode = []
    s,_ = env.reset()

    while True:
        a = pi(s) # hit or stay
        s_, r, terminated, truncated, _ = env.step(a) # take action

        episode.append((s, a, r))
        if terminated or truncated:
            if r == 1:
                win_cnt += 1
            elif r == -1:
                lose_cnt += 1
            else:
                draw_cnt += 1
            break
        s = s_

    G = 0

    visited_states = []
    print('[(status), action, reward]: ', episode)
    for s, a, r in episode[::-1]:
        G = GAMMA*G + r

        if s not in visited_states:
            Returns[s].append(G)
            V[s] = np.mean(Returns[s])
            visited_states.append(s)


    if i % 5000 == 0:
        print(f"episode = {i}/{num_episodes} completed")


print("Policy : stick threshold =  {}".format(stick_threshold))
print("win ratio = {:2f}%".format(100*win_cnt/num_episodes))
print("lose ratio = {:2f}%".format(100*lose_cnt/num_episodes))
print("draw ratio = {:2f}%".format(100*draw_cnt/num_episodes))
# Out:
# [(status), action, reward]:  [((12, 2, 0), 1, 0.0), ((18, 2, 0), 0, 1.0)]
# episode = 0/100000 completed
# [(status), action, reward]:  [((8, 4, 0), 1, 0.0), ((11, 4, 0), 1, 0.0), ((19, 4, 0), 0, 1.0)]
# [(status), action, reward]:  [((10, 3, 0), 1, 0.0), ((19, 3, 0), 0, 1.0)]
# [(status), action, reward]:  [((11, 10, 0), 1, 0.0), ((21, 10, 0), 0, 1.0)]
# [(status), action, reward]:  [((16, 7, 1), 1, 0.0), ((16, 7, 0), 1, 0.0), ((21, 7, 0), 0, 1.0)]
# [(status), action, reward]:  [((18, 6, 0), 0, -1.0)]
# [(status), action, reward]:  [((19, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((15, 8, 0), 1, -1.0)]
# [(status), action, reward]:  [((7, 10, 0), 1, 0.0), ((13, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((20, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((10, 7, 0), 1, 0.0), ((19, 7, 0), 0, 1.0)]
# [(status), action, reward]:  [((18, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((9, 3, 0), 1, 0.0), ((13, 3, 0), 1, 0.0), ((21, 3, 0), 0, 1.0)]
# [(status), action, reward]:  [((17, 3, 0), 1, 0.0), ((18, 3, 0), 0, -1.0)]
# [(status), action, reward]:  [((20, 2, 0), 0, 1.0)]
# [(status), action, reward]:  [((15, 4, 1), 1, 0.0), ((17, 4, 1), 1, 0.0), ((18, 4, 1), 0, 1.0)]
# [(status), action, reward]:  [((18, 1, 0), 0, -1.0)]
# [(status), action, reward]:  [((16, 3, 1), 1, 0.0), ((12, 3, 0), 1, -1.0)]
# [(status), action, reward]:  [((6, 10, 0), 1, 0.0), ((9, 10, 0), 1, 0.0), ((12, 10, 0), 1, 0.0), ((14, 10, 0), 1, 0.0), ((19, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((11, 10, 0), 1, 0.0), ((16, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((21, 10, 1), 0, 1.0)]
# [(status), action, reward]:  [((21, 4, 1), 0, 1.0)]
# [(status), action, reward]:  [((11, 5, 0), 1, 0.0), ((18, 5, 0), 0, -1.0)]
# [(status), action, reward]:  [((11, 10, 0), 1, 0.0), ((21, 10, 0), 0, 1.0)]
# [(status), action, reward]:  [((14, 7, 0), 1, -1.0)]
# [(status), action, reward]:  [((10, 3, 0), 1, 0.0), ((21, 3, 1), 0, 1.0)]
# [(status), action, reward]:  [((13, 2, 0), 1, 0.0), ((21, 2, 0), 0, 1.0)]
# [(status), action, reward]:  [((21, 9, 1), 0, 1.0)]
# [(status), action, reward]:  [((13, 10, 0), 1, 0.0), ((17, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((4, 9, 0), 1, 0.0), ((14, 9, 0), 1, -1.0)]
# [(status), action, reward]:  [((17, 9, 0), 1, -1.0)]
# [(status), action, reward]:  [((5, 4, 0), 1, 0.0), ((14, 4, 0), 1, 0.0), ((20, 4, 0), 0, -1.0)]
# [(status), action, reward]:  [((11, 1, 0), 1, 0.0), ((21, 1, 0), 0, 1.0)]
# [(status), action, reward]:  [((21, 10, 1), 0, 1.0)]
# [(status), action, reward]:  [((11, 9, 0), 1, 0.0), ((20, 9, 0), 0, -1.0)]
# [(status), action, reward]:  [((19, 9, 0), 0, 1.0)]
# [(status), action, reward]:  [((21, 9, 1), 0, 1.0)]
# [(status), action, reward]:  [((18, 8, 0), 0, 0.0)]
# [(status), action, reward]:  [((13, 10, 0), 1, 0.0), ((15, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((17, 6, 1), 1, 0.0), ((20, 6, 1), 0, 1.0)]
# [(status), action, reward]:  [((7, 10, 0), 1, 0.0), ((14, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((18, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((10, 1, 0), 1, 0.0), ((18, 1, 0), 0, -1.0)]
# [(status), action, reward]:  [((20, 10, 0), 0, 0.0)]
# [(status), action, reward]:  [((21, 4, 1), 0, 1.0)]
# [(status), action, reward]:  [((19, 9, 0), 0, 0.0)]
# [(status), action, reward]:  [((11, 5, 0), 1, 0.0), ((17, 5, 0), 1, 0.0), ((21, 5, 0), 0, 1.0)]
# [(status), action, reward]:  [((7, 9, 0), 1, 0.0), ((17, 9, 0), 1, 0.0), ((20, 9, 0), 0, 1.0)]
# [(status), action, reward]:  [((16, 4, 1), 1, 0.0), ((19, 4, 1), 0, 1.0)]
# [(status), action, reward]:  [((17, 5, 0), 1, -1.0)]
# [(status), action, reward]:  [((13, 4, 0), 1, -1.0)]
# [(status), action, reward]:  [((13, 3, 1), 1, 0.0), ((12, 3, 0), 1, 0.0), ((17, 3, 0), 1, -1.0)]
# [(status), action, reward]:  [((16, 6, 1), 1, 0.0), ((12, 6, 0), 1, -1.0)]
# [(status), action, reward]:  [((19, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((14, 6, 0), 1, -1.0)]
# [(status), action, reward]:  [((9, 5, 0), 1, 0.0), ((15, 5, 0), 1, -1.0)]
# [(status), action, reward]:  [((8, 10, 0), 1, 0.0), ((16, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((20, 4, 0), 0, 1.0)]
# [(status), action, reward]:  [((7, 6, 0), 1, 0.0), ((10, 6, 0), 1, 0.0), ((16, 6, 0), 1, 0.0), ((19, 6, 0), 0, 0.0)]
# [(status), action, reward]:  [((14, 9, 1), 1, 0.0), ((14, 9, 0), 1, 0.0), ((17, 9, 0), 1, 0.0), ((19, 9, 0), 0, 0.0)]
# [(status), action, reward]:  [((13, 4, 0), 1, -1.0)]
# [(status), action, reward]:  [((19, 5, 0), 0, 1.0)]
# [(status), action, reward]:  [((17, 4, 0), 1, -1.0)]
# [(status), action, reward]:  [((8,
 8, 0), 1, -1.0)]
# [(status), action, reward]:  [((12, 10, 0), 1, 0.0), ((14, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((12, 10, 0), 1, 0.0), ((14, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((18, 7, 0), 0, 1.0)]
# [(status), action, reward]:  [((9, 3, 0), 1, 0.0), ((19, 3, 0), 0, -1.0)]
# [(status), action, reward]:  [((10, 10, 0), 1, 0.0), ((20, 10, 0), 0, 0.0)]
# [(status), action, reward]:  [((19, 2, 0), 0, 1.0)]
# [(status), action, reward]:  [((12, 8, 0), 1, 0.0), ((18, 8, 0), 0, 0.0)]
# [(status), action, reward]:  [((13, 8, 1), 1, 0.0), ((15, 8, 1), 1, 0.0), ((15, 8, 0), 1, 0.0), ((17, 8, 0), 1, -1.0)]
# [(status), action, reward]:  [((20, 3, 0), 0, 1.0)]
# [(status), action, reward]:  [((12, 6, 0), 1, 0.0), ((19, 6, 0), 0, 1.0)]
# [(status), action, reward]:  [((14, 10, 1), 1, 0.0), ((12, 10, 0), 1, 0.0), ((15, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((11, 10, 0), 1, 0.0), ((21, 10, 0), 0, 1.0)]
# [(status), action, reward]:  [((12, 9, 0), 1, 0.0), ((19, 9, 0), 0, 1.0)]
# [(status), action, reward]:  [((9, 2, 0), 1, 0.0), ((18, 2, 0), 0, -1.0)]
# [(status), action, reward]:  [((13, 10, 0), 1, 0.0), ((16, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((20, 9, 0), 0, 1.0)]
# [(status), action, reward]:  [((11, 10, 0), 1, 0.0), ((19, 10, 0), 0, 1.0)]
# [(status), action, reward]:  [((12, 4, 0), 1, 0.0), ((18, 4, 0), 0, 1.0)]
# [(status), action, reward]:  [((14, 1, 0), 1, -1.0)]
# [(status), action, reward]:  [((15, 6, 0), 1, -1.0)]
# [(status), action, reward]:  [((19, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((19, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((13, 7, 0), 1, -1.0)]
# [(status), action, reward]:  [((13, 8, 0), 1, -1.0)]
# [(status), action, reward]:  [((15, 10, 0), 1, 0.0), ((20, 10, 0), 0, 0.0)]
# [(status), action, reward]:  [((20, 1, 0), 0, -1.0)]
# [(status), action, reward]:  [((13, 10, 0), 1, -1.0)]
# [(status), action, reward]:  [((7, 10, 0), 1, 0.0), ((12, 10, 0), 1, 0.0), ((19, 10, 0), 0, -1.0)]
# [(status), action, reward]:  [((14, 7, 0), 1, 0.0), ((16, 7, 0), 1, 0.0), ((19, 7, 0), 0, 1.0)]
# [(status), action, reward]:  [((21, 4, 1), 0, 1.0)]
# [(status), action, reward]:  [((12, 9, 0), 1, 0.0), ((15, 9, 0), 1, -1.0)]
# [(status), action, reward]:  [((7, 4, 0), 1, 0.0), ((15, 4, 0), 1, 0.0), ((21, 4, 0), 0, 1.0)]
# [(status), action, reward]:  [((15, 10, 0), 1, 0.0), ((18, 10, 0), 0, 1.0)]
# [(status), action, reward]:  [((13, 9, 0), 1, 0.0), ((19, 9, 0), 0, 1.0)]
# [(status), action, reward]:  [((20, 4, 0), 0, -1.0)]
# [(status), action, reward]:  [((5, 1, 0), 1, 0.0), ((12, 1, 0), 1, -1.0)]
# [(status), action, reward]:  [((13, 1, 0), 1, 0.0), ((14, 1, 0), 1, 0.0), ((15, 1, 0), 1, -1.0)]
# [(status), action, reward]:  [((15, 10, 1), 1, 0.0), ((17, 10, 1), 1, 0.0), ((17, 10, 0), 1, 0.0), ((20, 10, 0), 0, 0.0)]
# [(status), action, reward]:  [((20, 9, 1), 0, 1.0)]
# [(status), action, reward]:  [((13, 9, 1), 1, 0.0), ((13, 9, 0), 1, -1.0)]
# Policy : stick threshold =  18
# win ratio = 40.387000%
# lose ratio = 50.887000%
# draw ratio = 8.726000%

# %%
#시각화
X, Y = np.meshgrid(
    np.arange(12, 22),   # player가 가진 카드 합계 (12~21)
    np.arange(1, 11))    # dealer가 공개한 카드 (1~10)

#V[(player의 hand 합계, dealer 공개 카드, 사용 가능한 에이스 보유)]
no_usable_ace = np.apply_along_axis(lambda idx: V[(idx[0], idx[1], False)],
                                    2, np.dstack([X, Y]))
usable_ace = np.apply_along_axis(lambda idx: V[(idx[0], idx[1], True)],
                                 2, np.dstack([X, Y]))

fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12, 4),
                               subplot_kw={'projection': '3d'})

ax0.plot_surface(X, Y, no_usable_ace, cmap=plt.cm.YlGnBu_r)
ax0.set_xlabel('Player Cards')
ax0.set_ylabel('Dealer open Cards')
ax0.set_zlabel('MC Estimated Value')
ax0.set_title('No Useable Ace')

ax1.plot_surface(X, Y, usable_ace, cmap=plt.cm.YlGnBu_r)
ax1.set_xlabel('Player Cards')
ax1.set_ylabel('Dealer open Cards')
ax1.set_zlabel('MC Estimated Value')
ax1.set_title('Useable Ace')

plt.show()

# %% [markdown]
# ## Monte Carlo : blackjack control

# %%
win_cnt = 0
lose_cnt =0
draw_cnt = 0
GAMMMA = 1

e = 0.2
num_episodes = 100_000

# %%
env = gym.make("Blackjack-v1", sab = True)
num_actions = env.action_space.n

# %%
##
pi = defaultdict(lambda: np.ones(num_actions, dtype = float)/num_actions)
Q = defaultdict(lambda: np.zeros(num_actions))
Returns = defaultdict(list)

# %%
for i in range(num_episodes):
    episode = []
    s, _ = env.reset()

    while True:
        P = pi[s] # policy
        # epsilon greedy
        a = np.random.choice(np.arange(len(P)), p = P) # action selection
        s_, r, terminated, truncated, _ = env.step(a) # take action
        episode.append((s, a, r)) # store episode

        if terminated or truncated:
            if r == 1:
                win_cnt += 1
            elif r ==  -1:
                lose_cnt += 1
            else:
                draw_cnt += 1
            break
        s = s_

    G = 0
    visited_state_action_pair = []
    for s, a, r in episode[::-1]:
        G = GAMMMA*G + r

        if (s, a) not in visited_state_action_pair:
            Returns[(s, a)].append(G)
            Q[s][a] = np.mean(Returns[(s, a)])
            visited_state_action_pair.append((s, a))


        A_star = np.argmax(Q[s])

        for a in range(num_actions):
            if a == A_star:
                pi[s][a] = 1 - e + e/num_actions

            else:
                pi[s][a] = e/num_actions

    if i % 1000 == 0:
        print(f"{i}/{num_episodes} episode completed")
# Out:
# 0/100000 episode completed
# 1000/100000 episode completed
# 2000/100000 episode completed
# 3000/100000 episode completed
# 4000/100000 episode completed
# 5000/100000 episode completed
# 6000/100000 episode completed
# 7000/100000 episode completed
# 8000/100000 episode completed
# 9000/100000 episode completed
# 10000/100000 episode completed
# 11000/100000 episode completed
# 12000/100000 episode completed
# 13000/100000 episode completed
# 14000/100000 episode completed
# 15000/100000 episode completed
# 16000/100000 episode completed
# 17000/100000 episode completed
# 18000/100000 episode completed
# 19000/100000 episode completed
# 20000/100000 episode completed
# 21000/100000 episode completed
# 22000/100000 episode completed
# 23000/100000 episode completed
# 24000/100000 episode completed
# 25000/100000 episode completed
# 26000/100000 episode completed
# 27000/100000 episode completed
# 28000/100000 episode completed
# 29000/100000 episode completed
# 30000/100000 episode completed
# 31000/100000 episode completed
# 32000/100000 episode completed
# 33000/100000 episode completed
# 34000/100000 episode completed
# 35000/100000 episode completed
# 36000/100000 episode completed
# 37000/100000 episode completed
# 38000/100000 episode completed
# 39000/100000 episode completed
# 40000/100000 episode completed
# 41000/100000 episode completed
# 42000/100000 episode completed
# 43000/100000 episode completed
# 44000/100000 episode completed
# 45000/100000 episode completed
# 46000/100000 episode completed
# 47000/100000 episode completed
# 48000/100000 episode completed
# 49000/100000 episode completed
# 50000/100000 episode completed
# 51000/100000 episode completed
# 52000/100000 episode completed
# 53000/100000 episode completed
# 54000/100000 episode completed
# 55000/100000 episode completed
# 56000/100000 episode completed
# 57000/100000 episode completed
# 58000/100000 episode completed
# 59000/100000 episode completed
# 60000/100000 episode completed
# 61000/100000 episode completed
# 62000/100000 episode completed
# 63000/100000 episode completed
# 64000/100000 episode completed
# 65000/100000 episode completed
# 66000/100000 episode completed
# 67000/100000 episode completed
# 68000/100000 episode completed
# 69000/100000 episode completed
# 70000/100000 episode completed
# 71000/100000 episode completed
# 72000/100000 episode completed
# 73000/100000 episode completed
# 74000/100000 episode completed
# 75000/100000 episode completed
# 76000/100000 episode completed
# 77000/100000 episode completed
# 78000/100000 episode completed
# 79000/100000 episode completed
# 80000/100000 episode completed
# 81000/100000 episode completed
# 82000/100000 episode completed
# 83000/100000 episode completed
# 84000/100000 episode completed
# 85000/100000 episode completed
# 86000/100000 episode completed
# 87000/100000 episode completed
# 88000/100000 episode completed
# 89000/100000 episode completed
# 90000/100000 episode completed
# 91000/100000 episode completed
# 92000/100000 episode completed
# 93000/100000 episode completed
# 94000/100000 episode completed
# 95000/100000 episode completed
# 96000/100000 episode completed
# 97000/100000 episode completed
# 98000/100000 episode completed
# 99000/100000 episode completed

# %%
print("승리 비율 = {:.2f}%".format(100*win_cnt/num_episodes))
print("패배 비율 = {:.2f}%".format(100*lose_cnt/num_episodes))
print("무승부 비율 = {:.2f}%".format(100*draw_cnt/num_episodes))
# Out:
# 승리 비율 = 39.80%
# 패배 비율 = 53.25%
# 무승부 비율 = 6.96%

# %%
V = defaultdict(float)
for state, actions in Q.items():
    action_value = np.max(actions)
    V[state] = action_value

# %%
sample_state = (17, 10, True)
optimal_action = np.argmax(Q[sample_state])
state_value = V[sample_state]

print(f"Optimal action = {optimal_action}")
print(f"State value = {state_value}")
# Out:
# Optimal action = 1
# State value = -0.2853185595567867

# %%
#시각화
X, Y = np.meshgrid(
    np.arange(12, 22),   # player가 가진 카드 합계 (12~21)
    np.arange(1, 11))    # dealer가 공개한 카드 (1~10)

#V[(player의 hand 합계, dealer 공개 카드, 사용 가능한 에이스 보유)]
no_usable_ace = np.apply_along_axis(lambda idx: V[(idx[0], idx[1], False)],
                                    2, np.dstack([X, Y]))
usable_ace = np.apply_along_axis(lambda idx: V[(idx[0], idx[1], True)],
                                 2, np.dstack([X, Y]))

fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12, 4),
                               subplot_kw={'projection': '3d'})

ax0.plot_surface(X, Y, no_usable_ace, cmap=plt.cm.YlGnBu_r)
ax0.set_xlabel('Player Cards')
ax0.set_ylabel('Dealer open Cards')
ax0.set_zlabel('MC Estimated Value')
ax0.set_title('No Useable Ace')

ax1.plot_surface(X, Y, usable_ace, cmap=plt.cm.YlGnBu_r)
ax1.set_xlabel('Player Cards')
ax1.set_ylabel('Dealer open Cards')
ax1.set_zlabel('MC Estimated Value')
ax1.set_title('Useable Ace')

plt.show()
